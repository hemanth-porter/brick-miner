# %%
import os
import openai
openai.api_key = "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"

# %%
from pydub import AudioSegment

song = AudioSegment.from_mp3("audio.mp3")

# PyDub handles time in milliseconds
ten_minutes = 5 * 60 * 1000

first_10_minutes = song[:ten_minutes]

first_10_minutes.export("audio_5.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='audio_5.mp3'>

# %%
audio_file = open("audio_5.mp3", "rb")
transcript = openai.Audio.transcribe("whisper-1", audio_file)

# %%
transcript['text']
# Out:
# 'दोस्तों मैंने कस्ट्मर केर वाली से बात किया है और थोड़ी दिर बात करने के बाद मैंने उसको इंप्रेस कर लिया था तो चले आज उसके रिकोडिंग सुनते हैं तो दोस्तों मैं आपको बता दो कि वीडियो थोड़ा लंबा हो गया है लेकिन लाइट में बहुत ज़्यादा मज़ा आने वाला तो आप वीडियो को इसकीप ना करें और वीडियो को पूरा ज़रूर देखें तो चले दोस्तों रिकोडिंग स्टार्ट करते हैं रिकोडिंग स्टार्ट करने से पहले मैं आपको बता दो कि वीडियो सिफ एंटर टन परपस के लिए बनाये गया तो आप ऐसा खुज से ट्राइं ना करें तो चले रिकोडिंग सुनते हैं और उनकी हाँ से जो भी रेजलूसियन की डेट प्रोवाइड की गई है वो है 26 फेज़ुरी या उससे पहले जो ने आपको प्रोवाइड की रेजलूसियन होगा वो प्रोवाइड किया जाएगा मैंम एक बात बोलो अब आप मेरी बी बात सुन लेंगी अगर मैंने प्रोड़ेक्ट में ले रहा था भाई का बद्दे था तो मुझे उसको गिफ्ट करना था तो अब उसका बद्दे भी पार हो गया है मैं उसको गिफ्ट नहीं कर पाया बिकोस अप फिलिप कार्ड यही कह सकते हैं क्योंकि मैं उसका डेलिवर्ड डेट जो मतलब सही नहीं है इस वाज़े से मैं कॉल करके थक चुका हूँ यह फाइब टाइम मैंने कॉल किया है बट कोई सुनवाई नहीं है 
# ...

# %%
print()
# Out:
# {
# ...

# %%
print(u'हिन्दी बोलना सीख रहे हो तो, कृपया अंग्रेजी के अलावा हिन्दी भाषा में भी बात करो।')
# Out:
# हिन्दी बोलना सीख रहे हो तो, कृपया अंग्रेजी के अलावा हिन्दी भाषा में भी बात करो।
